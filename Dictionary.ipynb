# %%
# when we aren't converting dictionary to list, in the output unnecessarily we are getting dict_
print(cgpa.items())
print(cgpa.values())
print(cgpa.keys())
# Out:
# dict_items([(1, 8.9), (2, 5.7), (4, 6.7), (7, 9.1), (8, 5.3)])
# dict_values([8.9, 5.7, 6.7, 9.1, 5.3])
# dict_keys([1, 2, 4, 7, 8])

# %%
# on converting dictionary to list, in the output dict_ doesn't come
cgpa={1:8.9,2:5.7,4:6.7,7:9.1,8:5.3}
print(list(cgpa.items()))
print(list(cgpa.values()))
print(list(cgpa.keys()))
# Out:
# [(1, 8.9), (2, 5.7), (4, 6.7), (7, 9.1), (8, 5.3)]
# [8.9, 5.7, 6.7, 9.1, 5.3]
# [1, 2, 4, 7, 8]

# %%
cgpa={1:8.9,2:5.7,4:6.7,7:9.1,8:5.3}
keylist=list(cgpa.keys())
vallist=list(cgpa.values())
minval=min(cgpa.values())
maxval=max(cgpa.values())
print(keylist)
print(vallist)
print("minvalue","key",keylist[vallist.index(minval)]) #fetching index of min value from vallist, we are searching for corresponding index in keylist
print("maxvalue","key",keylist[vallist.index(maxval)])
# Out:
# [1, 2, 4, 7, 8]
# [8.9, 5.7, 6.7, 9.1, 5.3]
# minvalue key 8
# maxvalue key 7

# %%
# method to find max and min key
cgpa={1:8.9,2:5.7,4:6.7,7:9.1,8:5.3}
keylist=list(cgpa.keys())
vallist=list(cgpa.values())
print("\n key having maximum key-",max(cgpa,key=cgpa.get))
print("\n key having minimum key-",min(cgpa,key=cgpa.get))
# Out:
#  key having maximum key- 7
#
#  key having minimum key- 8

# %%
cgpa={1:8.9,2:5.7,4:6.7,7:9.1,8:5.3}
keylist=list(cgpa.keys())
vallist=list(cgpa.values())
print(2 in cgpa.keys())
print(9 in cgpa.keys())
# Out:
# True
# False

# %%
age={'A':14,'B':15,'C':16,'D':17}
print(cgpa.items())
print(cgpa.values())
print(cgpa.keys())
# Out:
# dict_items([(1, 8.9), (2, 5.7), (4, 6.7), (7, 9.1), (8, 5.3)])
# dict_values([8.9, 5.7, 6.7, 9.1, 5.3])
# dict_keys([1, 2, 4, 7, 8])

# %%
age={'A':14,'B':15,'C':16,'D':17}
keylist=list(age.keys()) #to store the keys of dictionary into separate list
vallist=list(age.values())  #to store the values of dictionary into separate list
minval= min(age.values()) #to store min value in a variable named minval
maxval=max(age.values())   #to store max value in a variable named maxval
print("\n value=", minval,"\nkey= ",keylist[vallist.index(minval)])
print("\n value=", maxval,"\nkey= ",keylist[vallist.index(maxval)])
# Out:
#  value= 14
# key=  A
#
#  value= 17
# key=  D

# %%
#Another method to find key with min or max value
age={'A':14,'B':15,'C':16,'D':17}
print(min(age,key=age.get))
print(max(age,key=age.get))
# Out:
# A
# D

# %%
# searching a particular key and value in dictionary
age={'A':14,'B':15,'C':16,'D':17}
print("Searching key", 'A' in age.keys())
print("Searching key", 'A' not in age.keys())
print("Searching key", 'E' in age.keys())
print("Searching value", 15 in age.values())
# Out:
# Searching key True
# Searching key False
# Searching key False
# Searching value True

# %%
# merging two dictionary
cgpa= {1:8.9,2:5.6,4:9.7}
cgpa1={4:6.7,7:9.1,8:5.3}
cgpa1.update(cgpa)
print("CGPA after update",cgpa1)
print(cgpa)
# Out:
# CGPA after update {4: 9.7, 7: 9.1, 8: 5.3, 1: 8.9, 2: 5.6}
# {1: 8.9, 2: 5.6, 4: 9.7}

# %%
#merging two lists
a=[1,2,3,4]
b=['a','b','c','d']
b.update(a)
print(b)
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# /tmp/ipython-input-3333063133.py in <cell line: 0>()
#       2 a=[1,2,3,4]
#       3 b=['a','b','c','d']
# ----> 4 b.update(a)
#       5 print(b)
#
# AttributeError: 'list' object has no attribute 'update'

# %%
# Assignment given by maam
cars={'brand':'Ford','model':'Mustang','year':1964}
print("Dictionary elements",cars)
cars['colour']= 'red' #adding a new key and value in the dictionary
print("After adding colour",cars)
print("\nkeys --->",cars.keys()) #to print keys of the dictionary
print("\nvalues --->",cars.values()) #to print values of the dictionary
print("\nitems --->",cars.items()) #to print items of the dictionary
print("\nWhether model is present in cars or not",'model' in cars) #to check whether a particular key is present or not
# Out:
# Dictionary elements {'brand': 'Ford', 'model': 'Mustang', 'year': 1964}
# After adding colour {'brand': 'Ford', 'model': 'Mustang', 'year': 1964, 'colour': 'red'}
#
# keys ---> dict_keys(['brand', 'model', 'year', 'colour'])
#
# values ---> dict_values(['Ford', 'Mustang', 1964, 'red'])
#
# items ---> dict_items([('brand', 'Ford'), ('model', 'Mustang'), ('year', 1964), ('colour', 'red')])
#
# Whether model is present in cars or not True

# %%
print("\nkeys --->",list(cars.keys()))
print("\nvalues --->",list(cars.values()))
print("\nitems --->",list(cars.items()))
# Out:
# keys ---> ['brand', 'model', 'year', 'colour']
#
# values ---> ['ford', 'mustang', 1964, 'red']
#
# items ---> [('brand', 'ford'), ('model', 'mustang'), ('year', 1964), ('colour', 'red')]

# %%
cars={"brand":"ford","model":"mustang","year":1964}
print("dictionary ",cars)
# Out:
# dictionary  {'brand': 'ford', 'model': 'mustang', 'year': 1964}

# %%
keylist=list(cars.keys())
vallist=list(cars.values())
items=list(cars.items())
print(keylist)
print(vallist)
print(items)
# Out:
# ['brand', 'model', 'year']
# ['ford', 'mustang', 1964]
# [('brand', 'ford'), ('model', 'mustang'), ('year', 1964)]

# %%
cars["colour"]="red"
print(cars)
# Out:
# {'brand': 'ford', 'model': 'mustang', 'year': 1964, 'colour': 'red'}

# %%
print(" is model present" ,"model" in cars.keys())
# Out:
#  is model present True

# %%
keys=['movie','hero','release year']
values=['kantaara','rishav',2022]
keys.append(values)
print(keys)
# Out:
# ['movie', 'hero', 'release year', ['kantaara', 'rishav', 2022]]

# %%
# joining two lists into a dictionary using zip
keys=['movie','hero','release year']
values=['kantaara','rishav',2022]
print(dict(zip(keys,values)))
# Out:
# {'movie': 'kantaara', 'hero': 'rishav', 'release year': 2022}

# %%
keys=['movie','hero','release year']
values=['kantaara','rishav',2022]
dict={}
for i,j in :
  a=index.keys()
# Out:
#   File "/tmp/ipython-input-1519704057.py", line 4
#     for i,j in :
#                ^
# SyntaxError: invalid syntax

# %%
# joining two lists into a dictionary using proper concept
keys=['movie','hero','release year']
values=['kantaara','rishab',2022]
mdict={}
for i in range(len(keys)):
  mdict[keys[i]]=values[i]
print(mdict)
# Out:
# {'movie': 'kantaara', 'hero': 'rishab', 'release year': 2022}

# %%
# copying from one dictionary to another
# using '=' opeartor
dict1={"name":"john",10:[2,4,3]}
dict2=dict1
print(dict1)
print(dict2)
print("after doing change")
dict1.popitem()
print(dict1)
print(dict2)
# Out:
# {'name': 'john', 10: [2, 4, 3]}
# {'name': 'john', 10: [2, 4, 3]}
# after doing change
# {'name': 'john'}
# {'name': 'john'}

# %%
#using 'copy' method
dict1={"name":"john",10:[2,4,3]}
dict2=dict1.copy()
print(dict1)
print(dict2)
print("after doing change")
dict1.popitem()
print(dict1)
print(dict2)
# Out:
# {'name': 'john', 10: [2, 4, 3]}
# {'name': 'john', 10: [2, 4, 3]}
# after doing change
# {'name': 'john'}
# {'name': 'john', 10: [2, 4, 3]}
